# %%
from ultralytics import YOLO

model = YOLO('yolo11n.pt')
print("YOLO model loaded successfully.")
# Out:
# YOLO model loaded successfully.

# %%
import torch
torch.cuda.empty_cache()
print("GPU cache cleared")
# Out:
# GPU cache cleared

# %%
import torch

print("Torch:", torch.__version__)
print("CUDA Available:", torch.cuda.is_available())
if torch.cuda.is_available() and torch.cuda.device_count() > 0:
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("GPU: No GPU available")
# Out:
# Torch: 2.5.1+cu121
# CUDA Available: True
# GPU: NVIDIA GeForce RTX 4050 Laptop GPU

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

model.train(
    data=r"datasetyolo11\data.yaml",
    epochs=50,
    imgsz=256,
    batch=1,
    device=0,
    workers=0,
    amp=True,
    name="sushi_dataset_yolo11n"
)
# Out:
# Ultralytics 8.4.21  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...

# %%
from ultralytics import YOLO

# Load the best trained model
model = YOLO('runs/detect/train/weights/best.pt')
print("Best YOLO model loaded successfully.")
# Out:
# Best YOLO model loaded successfully.

# %%
model = YOLO(r"runs\detect\sushi_dataset33\weights\best.pt")

# Evaluate the model on the validation set
metrics = model.val(
    data=r"C:\Users\than2\OneDrive\เดสก์ท็อป\sushi_prj\dataset2\data.yaml"
)

# Print evaluation metrics
print("Evaluation Metrics:")
print(f"  Precision: {metrics.results_dict['metrics/precision(B)']:.4f}")
print(f"  Recall: {metrics.results_dict['metrics/recall(B)']:.4f}")
print(f"  mAP50: {metrics.results_dict['metrics/mAP50(B)']:.4f}")
print(f"  mAP50-95: {metrics.results_dict['metrics/mAP50-95(B)']:.4f}")
# Out:
# Ultralytics 8.4.21  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# YOLO11n summary (fused): 101 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 919.6393.0 MB/s, size: 104.7 KB)
# val: Scanning C:\Users\than2\OneDrive\เดสก์ท็อป\sushi_prj\dataset2\valid\labels.cache... 7 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 7/7  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.4s/it 8.4s
#                    all          7        158      0.281      0.528      0.324      0.108
#                Janback          6         33      0.218      0.303      0.231     0.0621
#                Jangold          7         32      0.284       0.75      0.462      0.159
#                 Janred          7         60      0.341      0.667      0.413      0.136
# ...

# %%
from IPython.display import Image as IPyImage

# Display Confusion Matrix
print("Confusion Matrix:")
display(IPyImage(filename='runs/detect/train9/confusion_matrix.png', width=600))
# Out:
# Confusion Matrix:

# %%
from IPython.display import Image as IPyImage

# Display Results Plot
print("Results Plot:")
display(IPyImage(filename='runs/detect/train9/results.png', width=600))
# Out:
# Results Plot:

# %%
from IPython.display import Image as IPyImage

# Display a sample validation batch prediction image
print("Sample Validation Batch Prediction Image:")
display(IPyImage(filename='runs/detect/train9/val_batch0_pred.jpg', width=800
))
# Out:
# Sample Validation Batch Prediction Image:
