# %%
from ultralytics import YOLO

model = YOLO('yolo11n.pt')
print("YOLO model loaded successfully.")
# Out:
# YOLO model loaded successfully.

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\than2\AppData\Local\Programs\Python\Python311\python.exe

# %%
import torch

print("Torch:", torch.__version__)
print("CUDA Available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# Torch: 2.5.1+cu121
# CUDA Available: True
# GPU: NVIDIA GeForce RTX 4050 Laptop GPU

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

model.train(
    data="C:\\Users\\than2\\OneDrive\\เดสก์ท็อป\\sushi_prj\\dataset2\\data.yaml",
    epochs=100,
    device=0  # ใช้ GPU ตัวแรก
)
# Out:
# Ultralytics 8.4.21  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...

# %%
from ultralytics import YOLO

# Load the best trained model
model = YOLO('runs/detect/train/weights/best.pt')
print("Best YOLO model loaded successfully.")
# Out:
# Best YOLO model loaded successfully.

# %%
# Evaluate the model on the validation set
metrics = model.val()

# Print evaluation metrics
print("Evaluation Metrics:")
print(f"  Precision: {metrics.results_dict['metrics/precision(B)']:.4f}")
print(f"  Recall: {metrics.results_dict['metrics/recall(B)']:.4f}")
print(f"  mAP50: {metrics.results_dict['metrics/mAP50(B)']:.4f}")
print(f"  mAP50-95: {metrics.results_dict['metrics/mAP50-95(B)']:.4f}")
# Out:
# Ultralytics 8.4.21  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# YOLO11n summary (fused): 101 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 1490.6808.9 MB/s, size: 176.0 KB)
# val: Scanning C:\Users\than2\OneDrive\เดสก์ท็อป\sushi_prj\dataset2\valid\labels.cache... 7 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 7/7  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.2s/it 5.2s
#                    all          7        158      0.853      0.735      0.807      0.314
#                Janback          6         33      0.873      0.627      0.726      0.258
#                Jangold          7         32      0.895      0.801      0.844      0.291
#                 Janred          7         60      0.871      0.784      0.901      0.396
# ...

# %%
from IPython.display import Image as IPyImage

# Display Confusion Matrix
print("Confusion Matrix:")
display(IPyImage(filename='runs/detect/train8/confusion_matrix.png', width=600))
# Out:
# Confusion Matrix:

# %%
from IPython.display import Image as IPyImage

# Display Results Plot
print("Results Plot:")
display(IPyImage(filename='runs/detect/train8/results.png', width=600))
# Out:
# Results Plot:

# %%
from IPython.display import Image as IPyImage

# Display a sample validation batch prediction image
print("Sample Validation Batch Prediction Image:")
display(IPyImage(filename='runs/detect/train8/val_batch0_pred.jpg', width=800
))
# Out:
# Sample Validation Batch Prediction Image:
