# %%
from ultralytics import YOLO

model = YOLO('yolo11n.pt')
print("YOLO model loaded successfully.")
# Out:
# YOLO model loaded successfully.

# %%
import torch
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device Name: {torch.cuda.get_device_name(0)}")
else:
    print("Using CPU for training")
# Out:
# CUDA Available: True
# Device Name: NVIDIA GeForce RTX 4050 Laptop GPU

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

model.train(
    data="dataset/data.yaml",
    epochs=100,
    device=0  # ใช้ GPU ตัวแรก
)
# Out:
# Ultralytics 8.4.14  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...

# %%
from ultralytics import YOLO

# Load the best trained model
model = YOLO('runs/detect/train/weights/best.pt')
print("Best YOLO model loaded successfully.")
# Out:
# Best YOLO model loaded successfully.

# %%
# Evaluate the model on the validation set
metrics = model.val()

# Print evaluation metrics
print("Evaluation Metrics:")
print(f"  Precision: {metrics.results_dict['metrics/precision(B)']:.4f}")
print(f"  Recall: {metrics.results_dict['metrics/recall(B)']:.4f}")
print(f"  mAP50: {metrics.results_dict['metrics/mAP50(B)']:.4f}")
print(f"  mAP50-95: {metrics.results_dict['metrics/mAP50-95(B)']:.4f}")
# Out:
# Ultralytics 8.4.14  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# YOLO11n summary (fused): 101 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 591.9166.6 MB/s, size: 55.6 KB)
# val: Scanning C:\Users\than2\OneDrive\เดสก์ท็อป\sushi_prj\dataset\valid\labels.cache... 124 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 124/124  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.4it/s 3.3s0.3ss
#                    all        124        417      0.539      0.436      0.399      0.188
#                janback         21         28      0.456      0.286      0.238      0.121
#                jangold         23         32      0.765      0.306      0.361      0.169
#                 janred        101        275      0.467      0.628      0.523      0.212
# ...

# %%
from IPython.display import Image as IPyImage

# Display Confusion Matrix
print("Confusion Matrix:")
display(IPyImage(filename='runs/detect/train3/confusion_matrix.png', width=600))
# Out:
# Confusion Matrix:

# %%
from IPython.display import Image as IPyImage

# Display Results Plot
print("Results Plot:")
display(IPyImage(filename='runs/detect/train3/results.png', width=600))
# Out:
# Results Plot:

# %%
from IPython.display import Image as IPyImage

# Display a sample validation batch prediction image
print("Sample Validation Batch Prediction Image:")
display(IPyImage(filename='runs/detect/train3/val_batch0_pred.jpg', width=800
))
# Out:
# Sample Validation Batch Prediction Image:
